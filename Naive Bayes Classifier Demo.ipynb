# %% [markdown]
# Bayes Classification <br/>
# $$P(Y | x) = \frac{P(x|Y)P(Y)}{P(x)}$$
# Naive Bayes Assumption uses feature independence given the label <br/>
# $$P(Y | x) = \frac{\prod_i^d P(x_i | Y)P(Y)}{P(X)}$$

# %% [markdown]
# # Naive Bayes Classification for Text Classification

# %% [markdown]
# Give a text $S$ of the form $S = w_1, w_2, w_3, ...... w_d $. Where $w_i$'s are the words. We want find a label for the text. Which is done by using naive bayes classification.
# $$P(Y | S) = \frac{\prod_i^d P(w_i | Y)P(Y)}{P(S)}$$
# For this we need estimate $P(Y)$ and $P(w_i| Y)$ from the training data.

# %% [markdown]
# # Parameter Estimation

# %% [markdown]
# $$ P(Y= y_k) = \frac{count(Y= y_k)}{count( Y= ANY)} $$
# <br/>
# $$ P( X=x_j | Y=y_k) = \frac{Count(X= x_j\ \&\ Y = y_k)}{  Count(X= ANY\ \&\ Y = y_k) } $$
#
# So we need to estimate the following counts from the training data <br/>
# $count(Y= y_k)$ <br/> $count( Y= ANY)$ <br/> $Count(X= x_j\ \&\ Y = y_k)$ <br/>
# $Count(X= ANY\ \&\ Y = y_k)  $

# %% [markdown]
# For text for d words <br/>
#
# $$ log( P(Y = y_k | x) )  = log \big( P(Y=y_k) \big) + \sum_{i=1}^d log \big(P(X = x_j | Y= y_k ) \big)$$
# <br/>
# $$log( P(Y = y_k | x) )  = log \big( \frac{count(Y= y_k)}{count( Y= ANY)}   \big)  +  \sum_{i=1}^d log \big( \frac{Count(X= x_j\ \&\ Y = y_k)}{  Count(X= ANY\ \&\ Y = y_k) } \big) $$

# %%
import re
from collections import  defaultdict

# %% [markdown]
# # Dataset

# %%
f =  open('DBPedia.verysmall/verysmall_train.txt', 'r') 
i = 0 
for article in f:
    try :
        labels, line = article.split('\t')
    except :
            continue
    print(labels, line)
    i = i + 1
    if i > 10 :
        break
    
f.close()
# Out:
# American_film_directors  <http://dbpedia.org/resource/Allan_Dwan> <http://dbpedia.org/ontology/abstract> "Allan Dwan (3 April 1885 \u2013 28 December 1981) was a pioneering Canadian-born American motion picture director, producer and screenwriter."@en .
#
# Articles_containing_video_clips  <http://dbpedia.org/resource/Animation> <http://dbpedia.org/ontology/abstract> "Animation is the process of creating motion and shape change illusion by means of the rapid display of a sequence of static images that minimally differ from each other. The illusion\u2014as in motion pictures in general\u2014is thought to rely on the phi phenomenon. Animators are artists who specialize in the creation of animation.Animations can be recorded on either analogue media, such as a flip book, motion picture film, video tape, or on digital media, including formats such as animated GIF, Flash animation or digital video. To display animation, a digital camera, computer, or projector are used along with new technologies that are produced.Animation creation methods include the traditional animation creation method and those involving stop motion animation of two and three-dimensional objects, such as paper cutouts, puppets and clay figures. Images are displayed in a rapid succession, usually 24, 25, 30, or 60 frames per second."@en .
#
# Articles_containing_video_clips  <http://dbpedia.org/resource/Apollo_11> <http://dbpedia.org/ontology/abstract> "Apollo 11 was the spaceflight that landed the first humans on the Moon, Americans Neil Armstrong and Buzz Aldrin, on July 20, 1969, at 20:18 UTC. Armstrong became the first to step onto the lunar surface six hours later on July 21 at 02:56 UTC. Armstrong spent about two and a half hours outside the spacecraft, Aldrin slightly less, and together they collected 47.5 pounds (21.5 kg) of lunar material for return to Earth. The third member of the mission, Michael Collins, piloted the command spacecraft alone in lunar orbit until Armstrong and Aldrin returned to it just under a day later for the trip back to Earth.Launched by a Saturn V rocket from Kennedy Space Center in Merritt Island, Florida, on July 16, Apollo 11 was the fifth manned mission of NASA's Apollo program. The Apollo spacecraft had three parts: a Command Module (CM) with a cabin for the three astronauts, and the only part that landed back on Earth; a Service Module (SM), which supported the Command Module with propulsion, electrical power, oxygen, and water; and a Lunar Module (LM) for landing on the Moon. After being sent toward the Moon by the Saturn V's upper stage, the astronauts separated the spacecraft from it and traveled for three days until they entered into lunar orbit. Armstrong and Aldrin then moved into the Lunar Module and landed in the Sea of Tranquility. They stayed a total of about 21\u00BD hours on the lunar surface. After lifting off in the upper part of the Lunar Module and rejoining Collins in the Command Module, they returned to Earth and landed in the Pacific Ocean on July 24.Broadcast on live TV to a world-wide audience, Armstrong stepped onto the lunar surface and described the event as \"one small step for [a] man, one giant leap for mankind.\" Apollo 11 effectively ended the Space Race and fulfilled a national goal proposed in 1961 by the U.S. President John F. Kennedy in a speech before the U.S. Congress: \"before this decade is out, of landing a man on the Moon and returning him safely to the Earth.\""@en .
#
# Articles_containing_video_clips  <http://dbpedia.org/resource/Alkali_metal> <http://dbpedia.org/ontology/abstract> "The alkali metals are a group (column) in the periodic table consisting of the chemical elements lithium (Li), sodium (Na), potassium (K), rubidium (Rb), caesium (Cs), and francium (Fr). This group lies in the s-block of the periodic table as all alkali metals have their outermost electron in an s-orbital: this electron configuration results in their characteristic properties. The alkali metals provide the best example of group trends in properties in the periodic table, with elements exhibiting well-characterized homologous behaviour.The alkali metals have very similar properties: they are all shiny, soft, highly reactive metals at standard temperature and pressure and readily lose their outermost electron to form cations with charge +1. They can all be cut easily with a knife due to their softness, exposing a shiny surface that tarnishes rapidly in air due to oxidation by atmospheric moisture and oxygen. Because of their high reactivity, they must be stored under oil to prevent reaction with air, and are found naturally only in salts and never as the free element. In the modern IUPAC nomenclature, the alkali metals comprise the group 1 elements, excluding hydrogen (H), which is nominally a group 1 element but not normally considered to be an alkali metal as it rarely exhibits behaviour comparable to that of the alkali metals. All the alkali metals react with water, with the heavier alkali metals reacting more vigorously than the lighter ones.All the discovered alkali metals occur in nature: in order of abundance, sodium is the most abundant, followed by potassium, lithium, rubidium, caesium, and finally francium, which is very rare due to its extremely high radioactivity and thus occurs only in traces due to its presence in natural decay chains. Experiments have been conducted to attempt the synthesis of ununennium (Uue), which is likely to be the next member of the group, but they have all met with failure. However, ununennium may not be an alkali metal due to relativistic effects, which are predicted to have a large influence on the chemical properties of superheavy elements; even if it does turn out to be an alkali metal, it is predicted to have some differences in physical and chemical properties from its lighter homologues.Most alkali metals have many different applications. Two of the most well-known applications of the pure elements are rubidium and caesium atomic clocks, of which caesium atomic clocks are the most accurate and precise representation of time. A common application of the compounds of sodium is the sodium-vapour lamp, which emits very efficient light. Table salt, or sodium chloride, has been used since antiquity. Sodium and potassium are also essential elements, having major biological roles as electrolytes, and although the other alkali metals are not essential, they also have various effects on the body, both beneficial and harmful."@en .
#
# Articles_containing_video_clips  <http://dbpedia.org/resource/Atlantic_Ocean> <http://dbpedia.org/ontology/abstract> "The Atlantic Ocean is the world's second largest ocean, following the Pacific Ocean. With a total area of about 106,400,000 square kilometres (41,100,000 sq mi), it covers approximately 20 percent of the Earth's surface and about 29 percent of its water surface area. The first part of its name refers to Atlas of Greek mythology, making the Atlantic the \"Sea of Atlas\".The oldest known mention of \"Atlantic\" is in The Histories of Herodotus around 450 BC (Hdt. 1.202.4): Atlantis thalassa (Greek: \u1F08\u03C4\u03BB\u03B1\u03BD\u03C4\u1F76\u03C2 \u03B8\u03AC\u03BB\u03B1\u03C3\u03C3\u03B1; English: Sea of Atlas). The term Ethiopic Ocean, derived from Ethiopia, was applied to the southern Atlantic as late as the mid-19th century. Before Europeans discovered other oceans, their term \"ocean\" was synonymous with the waters beyond the Strait of Gibraltar that are now known as the Atlantic. The early Greeks believed this ocean to be a gigantic river encircling the world.The Atlantic Ocean occupies an elongated, S-shaped basin extending longitudinally between Eurasia and Africa to the east, and the Americas to the west. As one component of the interconnected global ocean, it is connected in the north to the Arctic Ocean, to the Pacific Ocean in the southwest, the Indian Ocean in the southeast, and the Southern Ocean in the south (other definitions describe the Atlantic as extending southward to Antarctica). The equator subdivides it into the North Atlantic Ocean and South Atlantic Ocean. The term \"Central Atlantic\" refers to the area between South America and Africa north of the Equator; while geographically part of the North Atlantic, its character is very different to the waters to the north between North America and Europe."@en .
#
# English-language_journals  <http://dbpedia.org/resource/Algorithms_(journal)> <http://dbpedia.org/ontology/abstract> "Algorithms is a peer-reviewed open access mathematics journal  covering all aspects of algorithm studies, including theory, experiment, design, analysis, and results.Coverage also includes computer data, information systems, software engineering, artificial intelligence, automation, and control systems.The journal is published by MDPI and was established in 2008. The editor-in-chief is Kazuo Iwama (Kyoto University). Publishing formats include reviews, original research articles, and short communications."@en .
#
# Windows_games  <http://dbpedia.org/resource/Asteroids_(video_game)> <http://dbpedia.org/ontology/abstract> "Asteroids is an arcade space shooter released in November 1979 by Atari, Inc. and designed by Lyle Rains and Ed Logg. The player controls a spaceship in an asteroid field which is periodically traversed by flying saucers. The object of the game is to shoot and destroy asteroids and saucers while not colliding with either, or being hit by the saucers' counter-fire. The game becomes harder as the number of asteroids increases.Asteroids was conceived during a meeting between Logg and Rains and used hardware developed by Howard Delman previously used for Lunar Lander. Based on an unfinished game titled Cosmos and inspired by Spacewar! and Computer Space, both early shoot 'em up video games, Asteroids\u200A'\u200B physics model and control scheme were derived by Logg from these earlier games and refined through trial and error.  The game is rendered on a vector display in a two-dimensional view that wraps around in both screen axes.Acclaimed by players and video game critics for its vector graphics, controls, and addictive gameplay, Asteroids was one of the first major hits of the golden age of arcade games. The game sold over 70,000 arcade cabinets and proved both popular with players and influential with developers. It has since been ported to multiple platforms. Asteroids was widely imitated and directly influenced two popular and often cloned arcade games, Defender and Gravitar, as well as many other video games."@en .
#
# American_film_directors,American_people_of_Irish_descent  <http://dbpedia.org/resource/Alfred_Hitchcock> <http://dbpedia.org/ontology/abstract> "Sir Alfred Joseph Hitchcock, KBE (13 August 1899 \u2013 29 April 1980) was an English  film director and producer. Often nicknamed \"The Master of Suspense\", he pioneered many techniques in the suspense and psychological thriller genres. After a successful career in British cinema in both silent films and early talkies, renowned as England's best director, Hitchcock moved to Hollywood in 1939 and became a US citizen in 1955.Over a career spanning more than half a century, Hitchcock fashioned for himself a distinctive and recognisable directorial style. He pioneered the use of a camera made to move in a way that mimics a person's gaze, forcing viewers to engage in a form of voyeurism. He framed shots to maximise anxiety, fear, or empathy, and used innovative film editing. His stories often feature fugitives on the run from the law alongside \"icy blonde\" female characters. Many of Hitchcock's films have twist endings and thrilling plots featuring depictions of violence, murder, and crime. Many of the mysteries, however, are used as decoys or \"MacGuffins\" that serve the film's themes and the psychological examinations of the characters. Hitchcock's films also borrow many themes from psychoanalysis and feature strong sexual overtones. Through his cameo appearances in his own films, interviews, film trailers, and the television program Alfred Hitchcock Presents, he became a cultural icon.Hitchcock directed more than fifty feature films in a career spanning six decades. Often regarded as the greatest British filmmaker, he came first in a 2007 poll of film critics in Britain's Daily Telegraph, which said: \"Unquestionably the greatest filmmaker to emerge from these islands, Hitchcock did more than any director to shape modern cinema, which would be utterly different without him. His flair was for narrative, cruelly withholding crucial information (from his characters and from us) and engaging the emotions of the audience like no one else.\" The magazine MovieMaker has described him as the most influential filmmaker of all time, and he is widely regarded as one of cinema's most significant artists."@en .
#
# Articles_containing_video_clips  <http://dbpedia.org/resource/Alexander_Graham_Bell> <http://dbpedia.org/ontology/abstract> "Alexander Graham Bell (March 3, 1847 \u2013 August 2, 1922) was an eminent  Scottish-born scientist, inventor, engineer and innovator who is credited with inventing the first practical telephone.Bell's father, grandfather, and brother had all been associated with work on elocution and speech, and both his mother and wife were deaf, profoundly influencing Bell's life's work. His research on hearing and speech further led him to experiment with hearing devices which eventually culminated in Bell being awarded the first U.S. patent for the telephone in 1876.  Bell considered his most famous invention an intrusion on his real work as a scientist and refused to have a telephone in his study.Many other inventions marked Bell's later life, including groundbreaking work in optical telecommunications, hydrofoils and aeronautics. In 1888, Bell became one of the founding members of the National Geographic Society."@en .
#
# American_film_directors,Deaths_from_myocardial_infarction  <http://dbpedia.org/resource/Andy_Warhol> <http://dbpedia.org/ontology/abstract> "Andy Warhol (/\u02C8w\u0254rh\u0252l/; August 6, 1928 \u2013 February 22, 1987) was an American artist who was a leading figure in the visual art movement known as pop art. His works explore the relationship between artistic expression, celebrity culture and advertisement that flourished by the 1960s. After a successful career as a commercial illustrator, Warhol became a renowned and sometimes controversial artist. The Andy Warhol Museum in his native city, Pittsburgh, Pennsylvania, holds an extensive permanent collection of art and archives. It is the largest museum in the United States dedicated to a single artist.Warhol's art used many types of media, including hand drawing, painting, printmaking, photography, silk screening, sculpture, film, and music. He was also a pioneer in computer-generated art using Amiga computers that were introduced in 1984, two years before his death. He founded Interview Magazine and was the author of numerous books, including The Philosophy of Andy Warhol and Popism: The Warhol Sixties. He managed and produced the Velvet Underground, a rock band which had a strong influence on the evolution of punk rock music. He is also notable as a gay man who lived openly as such before the gay liberation movement. His studio, The Factory, was a famous gathering place that brought together distinguished intellectuals, drag queens, playwrights, Bohemian street people, Hollywood celebrities, and wealthy patrons.Warhol has been the subject of numerous retrospective exhibitions, books, and feature and documentary films. He coined the widely used expression \"15 minutes of fame\". Many of his creations are very collectible and highly valuable. The highest price ever paid for a Warhol painting is US$105 million for a 1963 canvas titled \"Silver Car Crash (Double Disaster)\". A 2009 article in The Economist described Warhol as the \"bellwether of the art market\". Warhol's works include some of the most expensive paintings ever sold."@en .
#
# Articles_containing_video_clips  <http://dbpedia.org/resource/Atom> <http://dbpedia.org/ontology/abstract> "An atom is the smallest unit of matter that defines the chemical elements. Every solid, liquid, gas, and plasma is made up of neutral or ionized atoms. Atoms are very small: the size of atoms is measured in picometers \u2013 trillionths (10\u221212) of a meter.Every atom is composed of a nucleus made of one or more protons and usually an equal or similar number of neutrons (except hydrogen-1, which has no neutrons). Protons and neutrons together are called nucleons. The nucleus is surrounded by one or more electrons. Over 99.94% of the atom's mass is in the nucleus. The protons have a positive electric charge, the electrons have a negative electric charge, and the neutrons have no electric charge. If the number of protons and electrons are equal, that atom is electrically neutral. If an atom has a surplus or deficit of electrons relative to protons, then it has an overall positive or negative charge, and is called an ion.Electrons of an atom are attracted to the protons in an atomic nucleus by this electromagnetic force. The protons and neutrons in the nucleus are attracted to each other by a different force, the nuclear force, which is usually stronger than the electromagnetic force repelling the positively charged protons from one another. Under certain circumstances the repelling electromagnetic force becomes stronger than the nuclear force, and nucleons can be ejected from the nucleus, leaving behind a different element: nuclear decay resulting in nuclear transmutation.The number of protons in the nucleus defines what chemical element the atom belongs to: for example, all copper atoms contain 29 protons. The number of neutrons defines the isotope of the element. The electron(s) influences the magnetic properties of an atom. Atoms can attach to one or more other atoms by chemical bonds to form chemical compounds such as molecules. The ability of atoms to associate and dissociate is responsible for most of the physical changes observed in nature, and is the subject of the discipline of chemistry.Not all the mass of the universe is composed of atoms. Dark matter comprises more of the Universe than matter, and is composed not of atoms, but of particles of a currently unknown type. Also, the classical physics of Newton does not explain many of the properties and behavior of atoms and sub-atomic particles: the field of quantum mechanics has been developed to better do so."@en .

# %%
cls  = set()
vocab= set()

C = defaultdict(lambda: 0)
f =  open('DBPedia.verysmall/verysmall_train.txt', 'r')

# %%
for article in f:
    try :        
            labels, line = article.split('\t')
    except :
            continue
    C['Y=ANY'] = C['Y=ANY'] + 1
    labels = labels.split(',')
    for label in labels:
        label = label.replace(" ","")
        C['Y='+label] = C['Y='+label] + 1
        cls.add(label)
    line  = re.sub(r'[^a-zA-Z]', " ",re.sub(r'<.*>',"", line) ).split()[:-1]
        
    for word in line :
        word  = word.lower()
        word  = word.replace(" ","")
        vocab.add(word)
        for label in labels:
            label = label.replace(" ","")
            C['Y='+label + '^X=' +word] =  C['Y='+label + '^X=' +word] + 1
            C['Y='+label + '^X=ANY'] =  C['Y='+label + '^X=ANY'] + 1
        
f.close()


C['Nsize'] = len(vocab)
C['Nclass'] = len(cls)

# %%
import math

q_x =   1./C['Nsize']
q_y =   1./C['Nclass']

# %%
C
# Out:
# defaultdict(<function __main__.<lambda>>,
#             {'Y=ANY': 10497,
#              'Y=American_film_directors': 311,
#              'Y=American_film_directors^X=allan': 4,
#              'Y=American_film_directors^X=ANY': 44499,
#              'Y=American_film_directors^X=dwan': 1,
#              'Y=American_film_directors^X=april': 37,
#              'Y=American_film_directors^X=u': 494,
#              'Y=American_film_directors^X=december': 37,
#              'Y=American_film_directors^X=was': 485,
#              'Y=American_film_directors^X=a': 802,
#              'Y=American_film_directors^X=pioneering': 5,
#              'Y=American_film_directors^X=canadian': 8,
#              'Y=American_film_directors^X=born': 238,
#              'Y=American_film_directors^X=american': 366,
#              'Y=American_film_directors^X=motion': 29,
#              'Y=American_film_directors^X=picture': 51,
#              'Y=American_film_directors^X=director': 411,
#              'Y=American_film_directors^X=producer': 199,
#              'Y=American_film_directors^X=and': 1853,
#              'Y=American_film_directors^X=screenwriter': 124,
#              'Y=Articles_containing_video_clips': 1764,
#              'Y=Articles_containing_video_clips^X=animation': 81,
#              'Y=Articles_containing_video_clips^X=ANY': 359887,
#              'Y=Articles_containing_video_clips^X=is': 5736,
#              'Y=Articles_containing_video_clips^X=the': 26373,
#              'Y=Articles_containing_video_clips^X=process': 115,
#              'Y=Articles_containing_video_clips^X=of': 13191,
#              'Y=Articles_containing_video_clips^X=creating': 32,
#              'Y=Articles_containing_video_clips^X=motion': 137,
#              'Y=Articles_containing_video_clips^X=and': 11739,
#              'Y=Articles_containing_video_clips^X=shape': 61,
#              'Y=Articles_containing_video_clips^X=change': 65,
#              'Y=Articles_containing_video_clips^X=illusion': 12,
#              'Y=Articles_containing_video_clips^X=by': 2875,
#              'Y=Articles_containing_video_clips^X=means': 90,
#              'Y=Articles_containing_video_clips^X=rapid': 53,
#              'Y=Articles_containing_video_clips^X=display': 37,
#              'Y=Articles_containing_video_clips^X=a': 8591,
#              'Y=Articles_containing_video_clips^X=sequence': 42,
#              'Y=Articles_containing_video_clips^X=static': 12,
#              'Y=Articles_containing_video_clips^X=images': 73,
#              'Y=Articles_containing_video_clips^X=that': 1711,
#              'Y=Articles_containing_video_clips^X=minimally': 2,
#              'Y=Articles_containing_video_clips^X=differ': 16,
#              'Y=Articles_containing_video_clips^X=from': 2015,
#              'Y=Articles_containing_video_clips^X=each': 202,
#              'Y=Articles_containing_video_clips^X=other': 927,
#              'Y=Articles_containing_video_clips^X=u': 6582,
#              'Y=Articles_containing_video_clips^X=as': 3845,
#              'Y=Articles_containing_video_clips^X=in': 9332,
#              'Y=Articles_containing_video_clips^X=pictures': 32,
#              'Y=Articles_containing_video_clips^X=general': 154,
#              'Y=Articles_containing_video_clips^X=thought': 52,
#              'Y=Articles_containing_video_clips^X=to': 6891,
#              'Y=Articles_containing_video_clips^X=rely': 16,
#              'Y=Articles_containing_video_clips^X=on': 2282,
#              'Y=Articles_containing_video_clips^X=phi': 2,
#              'Y=Articles_containing_video_clips^X=phenomenon': 27,
#              'Y=Articles_containing_video_clips^X=animators': 5,
#              'Y=Articles_containing_video_clips^X=are': 2402,
#              'Y=Articles_containing_video_clips^X=artists': 29,
#              'Y=Articles_containing_video_clips^X=who': 330,
#              'Y=Articles_containing_video_clips^X=specialize': 3,
#              'Y=Articles_containing_video_clips^X=creation': 34,
#              'Y=Articles_containing_video_clips^X=animations': 11,
#              'Y=Articles_containing_video_clips^X=can': 694,
#              'Y=Articles_containing_video_clips^X=be': 1115,
#              'Y=Articles_containing_video_clips^X=recorded': 56,
#              'Y=Articles_containing_video_clips^X=either': 113,
#              'Y=Articles_containing_video_clips^X=analogue': 4,
#              'Y=Articles_containing_video_clips^X=media': 63,
#              'Y=Articles_containing_video_clips^X=such': 725,
#              'Y=Articles_containing_video_clips^X=flip': 3,
#              'Y=Articles_containing_video_clips^X=book': 46,
#              'Y=Articles_containing_video_clips^X=picture': 38,
#              'Y=Articles_containing_video_clips^X=film': 445,
#              'Y=Articles_containing_video_clips^X=video': 63,
#              'Y=Articles_containing_video_clips^X=tape': 22,
#              'Y=Articles_containing_video_clips^X=or': 2416,
#              'Y=Articles_containing_video_clips^X=digital': 60,
#              'Y=Articles_containing_video_clips^X=including': 344,
#              'Y=Articles_containing_video_clips^X=formats': 7,
#              'Y=Articles_containing_video_clips^X=animated': 45,
#              'Y=Articles_containing_video_clips^X=gif': 1,
#              'Y=Articles_containing_video_clips^X=flash': 7,
#              'Y=Articles_containing_video_clips^X=camera': 73,
#              'Y=Articles_containing_video_clips^X=computer': 87,
#              'Y=Articles_containing_video_clips^X=projector': 2,
#              'Y=Articles_containing_video_clips^X=used': 746,
#              'Y=Articles_containing_video_clips^X=along': 149,
#              'Y=Articles_containing_video_clips^X=with': 2346,
#              'Y=Articles_containing_video_clips^X=new': 486,
#              'Y=Articles_containing_video_clips^X=technologies': 22,
#              'Y=Articles_containing_video_clips^X=produced': 144,
#              'Y=Articles_containing_video_clips^X=methods': 50,
#              'Y=Articles_containing_video_clips^X=include': 188,
#              'Y=Articles_containing_video_clips^X=traditional': 74,
#              'Y=Articles_containing_video_clips^X=method': 37,
#              'Y=Articles_containing_video_clips^X=those': 117,
#              'Y=Articles_containing_video_clips^X=involving': 15,
#              'Y=Articles_containing_video_clips^X=stop': 41,
#              'Y=Articles_containing_video_clips^X=two': 524,
#              'Y=Articles_containing_video_clips^X=three': 257,
#              'Y=Articles_containing_video_clips^X=dimensional': 16,
#              'Y=Articles_containing_video_clips^X=objects': 98,
#              'Y=Articles_containing_video_clips^X=paper': 37,
#              'Y=Articles_containing_video_clips^X=cutouts': 1,
#              'Y=Articles_containing_video_clips^X=puppets': 1,
#              'Y=Articles_containing_video_clips^X=clay': 22,
#              'Y=Articles_containing_video_clips^X=figures': 20,
#              'Y=Articles_containing_video_clips^X=displayed': 10,
#              'Y=Articles_containing_video_clips^X=succession': 4,
#              'Y=Articles_containing_video_clips^X=usually': 255,
#              'Y=Articles_containing_video_clips^X=frames': 20,
#              'Y=Articles_containing_video_clips^X=per': 89,
#              'Y=Articles_containing_video_clips^X=second': 182,
#              'Y=Articles_containing_video_clips^X=apollo': 89,
#              'Y=Articles_containing_video_clips^X=was': 2552,
#              'Y=Articles_containing_video_clips^X=spaceflight': 21,
#              'Y=Articles_containing_video_clips^X=landed': 24,
#              'Y=Articles_containing_video_clips^X=first': 707,
#              'Y=Articles_containing_video_clips^X=humans': 80,
#              'Y=Articles_containing_video_clips^X=moon': 127,
#              'Y=Articles_containing_video_clips^X=americans': 55,
#              'Y=Articles_containing_video_clips^X=neil': 6,
#              'Y=Articles_containing_video_clips^X=armstrong': 10,
#              'Y=Articles_containing_video_clips^X=buzz': 3,
#              'Y=Articles_containing_video_clips^X=aldrin': 7,
#              'Y=Articles_containing_video_clips^X=july': 102,
#              'Y=Articles_containing_video_clips^X=at': 1122,
#              'Y=Articles_containing_video_clips^X=utc': 9,
#              'Y=Articles_containing_video_clips^X=became': 248,
#              'Y=Articles_containing_video_clips^X=step': 9,
#              'Y=Articles_containing_video_clips^X=onto': 20,
#              'Y=Articles_containing_video_clips^X=lunar': 84,
#              'Y=Articles_containing_video_clips^X=surface': 219,
#              'Y=Articles_containing_video_clips^X=six': 81,
#              'Y=Articles_containing_video_clips^X=hours': 46,
#              'Y=Articles_containing_video_clips^X=later': 220,
#              'Y=Articles_containing_video_clips^X=spent': 20,
#              'Y=Articles_containing_video_clips^X=about': 350,
#              'Y=Articles_containing_video_clips^X=half': 67,
#              'Y=Articles_containing_video_clips^X=outside': 70,
#              'Y=Articles_containing_video_clips^X=spacecraft': 78,
#              'Y=Articles_containing_video_clips^X=slightly': 39,
#              'Y=Articles_containing_video_clips^X=less': 105,
#              'Y=Articles_containing_video_clips^X=together': 79,
#              'Y=Articles_containing_video_clips^X=they': 738,
#              'Y=Articles_containing_video_clips^X=collected': 11,
#              'Y=Articles_containing_video_clips^X=pounds': 7,
#              'Y=Articles_containing_video_clips^X=kg': 34,
#              'Y=Articles_containing_video_clips^X=material': 89,
#              'Y=Articles_containing_video_clips^X=for': 2405,
#              'Y=Articles_containing_video_clips^X=return': 42,
#              'Y=Articles_containing_video_clips^X=earth': 301,
#              'Y=Articles_containing_video_clips^X=third': 105,
#              'Y=Articles_containing_video_clips^X=member': 118,
#              'Y=Articles_containing_video_clips^X=mission': 124,
#              'Y=Articles_containing_video_clips^X=michael': 9,
#              'Y=Articles_containing_video_clips^X=collins': 3,
#              'Y=Articles_containing_video_clips^X=piloted': 5,
#              'Y=Articles_containing_video_clips^X=command': 42,
#              'Y=Articles_containing_video_clips^X=alone': 26,
#              'Y=Articles_containing_video_clips^X=orbit': 98,
#              'Y=Articles_containing_video_clips^X=until': 246,
#              'Y=Articles_containing_video_clips^X=returned': 29,
#              'Y=Articles_containing_video_clips^X=it': 2380,
#              'Y=Articles_containing_video_clips^X=just': 70,
#              'Y=Articles_containing_video_clips^X=under': 237,
#              'Y=Articles_containing_video_clips^X=day': 146,
#              'Y=Articles_containing_video_clips^X=trip': 6,
#              'Y=Articles_containing_video_clips^X=back': 109,
#              'Y=Articles_containing_video_clips^X=launched': 79,
#              'Y=Articles_containing_video_clips^X=saturn': 19,
#              'Y=Articles_containing_video_clips^X=v': 54,
#              'Y=Articles_containing_video_clips^X=rocket': 40,
#              'Y=Articles_containing_video_clips^X=kennedy': 27,
#              'Y=Articles_containing_video_clips^X=space': 237,
#              'Y=Articles_containing_video_clips^X=center': 91,
#              'Y=Articles_containing_video_clips^X=merritt': 1,
#              'Y=Articles_containing_video_clips^X=island': 146,
#              'Y=Articles_containing_video_clips^X=florida': 26,
#              'Y=Articles_containing_video_clips^X=fifth': 27,
#              'Y=Articles_containing_video_clips^X=manned': 33,
#              'Y=Articles_containing_video_clips^X=nasa': 71,
#              'Y=Articles_containing_video_clips^X=s': 2288,
#              'Y=Articles_containing_video_clips^X=program': 96,
#              'Y=Articles_containing_video_clips^X=had': 342,
#              'Y=Articles_containing_video_clips^X=parts': 118,
#              'Y=Articles_containing_video_clips^X=module': 38,
#              'Y=Articles_containing_video_clips^X=cm': 66,
#              'Y=Articles_containing_video_clips^X=cabin': 6,
#              'Y=Articles_containing_video_clips^X=astronauts': 20,
#              'Y=Articles_containing_video_clips^X=only': 390,
#              'Y=Articles_containing_video_clips^X=part': 299,
#              'Y=Articles_containing_video_clips^X=service': 135,
#              'Y=Articles_containing_video_clips^X=sm': 3,
#              'Y=Articles_containing_video_clips^X=which': 1351,
#              'Y=Articles_containing_video_clips^X=supported': 39,
#              'Y=Articles_containing_video_clips^X=propulsion': 15,
#              'Y=Articles_containing_video_clips^X=electrical': 44,
#              'Y=Articles_containing_video_clips^X=power': 184,
#              'Y=Articles_containing_video_clips^X=oxygen': 30,
#              'Y=Articles_containing_video_clips^X=water': 381,
#              'Y=Articles_containing_video_clips^X=lm': 10,
#              'Y=Articles_containing_video_clips^X=landing': 65,
#              'Y=Articles_containing_video_clips^X=after': 534,
#              'Y=Articles_containing_video_clips^X=being': 277,
#              'Y=Articles_containing_video_clips^X=sent': 20,
#              'Y=Articles_containing_video_clips^X=toward': 35,
#              'Y=Articles_containing_video_clips^X=upper': 45,
#              'Y=Articles_containing_video_clips^X=stage': 60,
#              'Y=Articles_containing_video_clips^X=separated': 26,
#              'Y=Articles_containing_video_clips^X=traveled': 7,
#              'Y=Articles_containing_video_clips^X=days': 87,
#              'Y=Articles_containing_video_clips^X=entered': 33,
#              'Y=Articles_containing_video_clips^X=into': 577,
#              'Y=Articles_containing_video_clips^X=then': 193,
#              'Y=Articles_containing_video_clips^X=moved': 39,
#              'Y=Articles_containing_video_clips^X=sea': 185,
#              'Y=Articles_containing_video_clips^X=tranquility': 1,
#              'Y=Articles_containing_video_clips^X=stayed': 5,
#              'Y=Articles_containing_video_clips^X=total': 96,
#              'Y=Articles_containing_video_clips^X=bd': 42,
#              'Y=Articles_containing_video_clips^X=lifting': 13,
#              'Y=Articles_containing_video_clips^X=off': 122,
#              'Y=Articles_containing_video_clips^X=rejoining': 2,
#              'Y=Articles_containing_video_clips^X=pacific': 95,
#              'Y=Articles_containing_video_clips^X=ocean': 127,
#              'Y=Articles_containing_video_clips^X=broadcast': 21,
#              'Y=Articles_containing_video_clips^X=live': 94,
#              'Y=Articles_containing_video_clips^X=tv': 14,
#              'Y=Articles_containing_video_clips^X=world': 718,
#              'Y=Articles_containing_video_clips^X=wide': 100,
#              'Y=Articles_containing_video_clips^X=audience': 18,
#              'Y=Articles_containing_video_clips^X=stepped': 4,
#              'Y=Articles_containing_video_clips^X=described': 84,
#              'Y=Articles_containing_video_clips^X=event': 47,
#              'Y=Articles_containing_video_clips^X=one': 781,
#              'Y=Articles_containing_video_clips^X=small': 295,
#              'Y=Articles_containing_video_clips^X=man': 87,
#              'Y=Articles_containing_video_clips^X=giant': 27,
#              'Y=Articles_containing_video_clips^X=leap': 2,
#              'Y=Articles_containing_video_clips^X=mankind': 3,
#              'Y=Articles_containing_video_clips^X=effectively': 15,
#              'Y=Articles_containing_video_clips^X=ended': 35,
#              'Y=Articles_containing_video_clips^X=race': 51,
#              'Y=Articles_containing_video_clips^X=fulfilled': 3,
#              'Y=Articles_containing_video_clips^X=national': 300,
#              'Y=Articles_containing_video_clips^X=goal': 40,
#              'Y=Articles_containing_video_clips^X=proposed': 27,
#              'Y=Articles_containing_video_clips^X=president': 186,
#              'Y=Articles_containing_video_clips^X=john': 65,
#              'Y=Articles_containing_video_clips^X=f': 382,
#              'Y=Articles_containing_video_clips^X=speech': 29,
#              'Y=Articles_containing_video_clips^X=before': 167,
#              'Y=Articles_containing_video_clips^X=congress': 58,
#              'Y=Articles_containing_video_clips^X=this': 767,
#              'Y=Articles_containing_video_clips^X=decade': 25,
#              'Y=Articles_containing_video_clips^X=out': 157,
#              'Y=Articles_containing_video_clips^X=returning': 15,
#              'Y=Articles_containing_video_clips^X=him': 96,
#              'Y=Articles_containing_video_clips^X=safely': 10,
#              'Y=Articles_containing_video_clips^X=alkali': 18,
#              'Y=Articles_containing_video_clips^X=metals': 21,
#              'Y=Articles_containing_video_clips^X=group': 160,
#              'Y=Articles_containing_video_clips^X=column': 10,
#              'Y=Articles_containing_video_clips^X=periodic': 18,
#              'Y=Articles_containing_video_clips^X=table': 21,
#              'Y=Articles_containing_video_clips^X=consisting': 40,
#              'Y=Articles_containing_video_clips^X=chemical': 66,
#              'Y=Articles_containing_video_clips^X=elements': 70,
#              'Y=Articles_containing_video_clips^X=lithium': 3,
#              'Y=Articles_containing_video_clips^X=li': 14,
#              'Y=Articles_containing_video_clips^X=sodium': 13,
#              'Y=Articles_containing_video_clips^X=na': 9,
#              'Y=Articles_containing_video_clips^X=potassium': 26,
#              'Y=Articles_containing_video_clips^X=k': 83,
#              'Y=Articles_containing_video_clips^X=rubidium': 4,
#              'Y=Articles_containing_video_clips^X=rb': 1,
#              'Y=Articles_containing_video_clips^X=caesium': 15,
#              'Y=Articles_containing_video_clips^X=cs': 5,
#              'Y=Articles_containing_video_clips^X=francium': 2,
#              'Y=Articles_containing_video_clips^X=fr': 1,
#              'Y=Articles_containing_video_clips^X=lies': 23,
#              'Y=Articles_containing_video_clips^X=block': 15,
#              'Y=Articles_containing_video_clips^X=all': 475,
#              'Y=Articles_containing_video_clips^X=have': 897,
#              'Y=Articles_containing_video_clips^X=their': 770,
#              'Y=Articles_containing_video_clips^X=outermost': 3,
#              'Y=Articles_containing_video_clips^X=electron': 20,
#              'Y=Articles_containing_video_clips^X=an': 1552,
#              'Y=Articles_containing_video_clips^X=orbital': 23,
#              'Y=Articles_containing_video_clips^X=configuration': 11,
#              'Y=Articles_containing_video_clips^X=results': 30,
#              'Y=Articles_containing_video_clips^X=characteristic': 17,
#              'Y=Articles_containing_video_clips^X=properties': 33,
#              'Y=Articles_containing_video_clips^X=provide': 46,
#              'Y=Articles_containing_video_clips^X=best': 103,
#              'Y=Articles_containing_video_clips^X=example': 109,
#              'Y=Articles_containing_video_clips^X=trends': 4,
#              'Y=Articles_containing_video_clips^X=exhibiting': 4,
#              'Y=Articles_containing_video_clips^X=well': 318,
#              'Y=Articles_containing_video_clips^X=characterized': 33,
#              'Y=Articles_containing_video_clips^X=homologous': 2,
#              'Y=Articles_containing_video_clips^X=behaviour': 27,
#              'Y=Articles_containing_video_clips^X=very': 207,
#              'Y=Articles_containing_video_clips^X=similar': 166,
#              'Y=Articles_containing_video_clips^X=shiny': 3,
#              'Y=Articles_containing_video_clips^X=soft': 36,
#              'Y=Articles_containing_video_clips^X=highly': 59,
#              'Y=Articles_containing_video_clips^X=reactive': 4,
#              'Y=Articles_containing_video_clips^X=standard': 59,
#              'Y=Articles_containing_video_clips^X=temperature': 118,
#              'Y=Articles_containing_video_clips^X=pressure': 103,
#              'Y=Articles_containing_video_clips^X=readily': 11,
#              'Y=Articles_containing_video_clips^X=lose': 6,
#              'Y=Articles_containing_video_clips^X=form': 276,
#              'Y=Articles_containing_video_clips^X=cations': 1,
#              'Y=Articles_containing_video_clips^X=charge': 23,
#              'Y=Articles_containing_video_clips^X=cut': 24,
#              'Y=Articles_containing_video_clips^X=easily': 29,
#              'Y=Articles_containing_video_clips^X=knife': 3,
#              'Y=Articles_containing_video_clips^X=due': 182,
#              'Y=Articles_containing_video_clips^X=softness': 1,
#              'Y=Articles_containing_video_clips^X=exposing': 1,
#              'Y=Articles_containing_video_clips^X=tarnishes': 1,
#              'Y=Articles_containing_video_clips^X=rapidly': 37,
#              'Y=Articles_containing_video_clips^X=air': 329,
#              'Y=Articles_containing_video_clips^X=oxidation': 8,
#              'Y=Articles_containing_video_clips^X=atmospheric': 44,
#              'Y=Articles_containing_video_clips^X=moisture': 10,
#              'Y=Articles_containing_video_clips^X=because': 192,
#              'Y=Articles_containing_video_clips^X=high': 256,
#              'Y=Articles_containing_video_clips^X=reactivity': 1,
#              'Y=Articles_containing_video_clips^X=must': 44,
#              'Y=Articles_containing_video_clips^X=stored': 17,
#              'Y=Articles_containing_video_clips^X=oil': 83,
#              'Y=Articles_containing_video_clips^X=prevent': 32,
#              'Y=Articles_containing_video_clips^X=reaction': 19,
#              'Y=Articles_containing_video_clips^X=found': 251,
#              'Y=Articles_containing_video_clips^X=naturally': 23,
#              'Y=Articles_containing_video_clips^X=salts': 8,
#              'Y=Articles_containing_video_clips^X=never': 41,
#              'Y=Articles_containing_video_clips^X=free': 94,
#              'Y=Articles_containing_video_clips^X=element': 31,
#              'Y=Articles_containing_video_clips^X=modern': 212,
#              'Y=Articles_containing_video_clips^X=iupac': 1,
#              'Y=Articles_containing_video_clips^X=nomenclature': 4,
#              'Y=Articles_containing_video_clips^X=comprise': 9,
#              'Y=Articles_containing_video_clips^X=excluding': 10,
#              'Y=Articles_containing_video_clips^X=hydrogen': 37,
#              'Y=Articles_containing_video_clips^X=h': 90,
#              'Y=Articles_containing_video_clips^X=nominally': 2,
#              'Y=Articles_containing_video_clips^X=but': 704,
#              'Y=Articles_containing_video_clips^X=not': 568,
#              'Y=Articles_containing_video_clips^X=normally': 42,
#              'Y=Articles_containing_video_clips^X=considered': 168,
#              'Y=Articles_containing_video_clips^X=metal': 68,
#              'Y=Articles_containing_video_clips^X=rarely': 23,
#              'Y=Articles_containing_video_clips^X=exhibits': 5,
#              'Y=Articles_containing_video_clips^X=comparable': 13,
#              'Y=Articles_containing_video_clips^X=react': 4,
#              'Y=Articles_containing_video_clips^X=heavier': 24,
#              'Y=Articles_containing_video_clips^X=reacting': 2,
#              'Y=Articles_containing_video_clips^X=more': 563,
#              'Y=Articles_containing_video_clips^X=vigorously': 2,
#              'Y=Articles_containing_video_clips^X=than': 508,
#              'Y=Articles_containing_video_clips^X=lighter': 13,
#              'Y=Articles_containing_video_clips^X=ones': 19,
#              'Y=Articles_containing_video_clips^X=discovered': 48,
#              'Y=Articles_containing_video_clips^X=occur': 65,
#              'Y=Articles_containing_video_clips^X=nature': 58,
#              'Y=Articles_containing_video_clips^X=order': 96,
#              'Y=Articles_containing_video_clips^X=abundance': 6,
#              'Y=Articles_containing_video_clips^X=most': 824,
#              'Y=Articles_containing_video_clips^X=abundant': 24,
#              'Y=Articles_containing_video_clips^X=followed': 56,
#              'Y=Articles_containing_video_clips^X=finally': 22,
#              'Y=Articles_containing_video_clips^X=rare': 39,
#              'Y=Articles_containing_video_clips^X=its': 1223,
#              'Y=Articles_containing_video_clips^X=extremely': 47,
#              'Y=Articles_containing_video_clips^X=radioactivity': 1,
#              'Y=Articles_containing_video_clips^X=thus': 80,
#              'Y=Articles_containing_video_clips^X=occurs': 59,
#              'Y=Articles_containing_video_clips^X=traces': 6,
#              'Y=Articles_containing_video_clips^X=presence': 37,
#              'Y=Articles_containing_video_clips^X=natural': 110,
#              'Y=Articles_containing_video_clips^X=decay': 12,
#              'Y=Articles_containing_video_clips^X=chains': 7,
#              'Y=Articles_containing_video_clips^X=experiments': 28,
#              'Y=Articles_containing_video_clips^X=been': 652,
#              'Y=Articles_containing_video_clips^X=conducted': 35,
#              'Y=Articles_containing_video_clips^X=attempt': 39,
#              'Y=Articles_containing_video_clips^X=synthesis': 15,
#              'Y=Articles_containing_video_clips^X=ununennium': 2,
#              'Y=Articles_containing_video_clips^X=uue': 1,
#              'Y=Articles_containing_video_clips^X=likely': 19,
#              'Y=Articles_containing_video_clips^X=next': 37,
#              'Y=Articles_containing_video_clips^X=met': 13,
#              'Y=Articles_containing_video_clips^X=failure': 29,
#              'Y=Articles_containing_video_clips^X=however': 179,
#              'Y=Articles_containing_video_clips^X=may': 544,
#              'Y=Articles_containing_video_clips^X=relativistic': 2,
#              'Y=Articles_containing_video_clips^X=effects': 89,
#              'Y=Articles_containing_video_clips^X=predicted': 11,
#              'Y=Articles_containing_video_clips^X=large': 362,
#              'Y=Articles_containing_video_clips^X=influence': 53,
#              'Y=Articles_containing_video_clips^X=superheavy': 2,
#              'Y=Articles_containing_video_clips^X=even': 142,
#              'Y=Articles_containing_video_clips^X=if': 130,
#              'Y=Articles_containing_video_clips^X=does': 66,
#              'Y=Articles_containing_video_clips^X=turn': 41,
#              'Y=Articles_containing_video_clips^X=some': 570,
#              'Y=Articles_containing_video_clips^X=differences': 28,
#              'Y=Articles_containing_video_clips^X=physical': 79,
#              'Y=Articles_containing_video_clips^X=homologues': 1,
#              'Y=Articles_containing_video_clips^X=many': 523,
#              'Y=Articles_containing_video_clips^X=different': 186,
#              'Y=Articles_containing_video_clips^X=applications': 65,
#              'Y=Articles_containing_video_clips^X=known': 692,
#              'Y=Articles_containing_video_clips^X=pure': 12,
#              'Y=Articles_containing_video_clips^X=atomic': 40,
#              'Y=Articles_containing_video_clips^X=clocks': 4,
#              'Y=Articles_containing_video_clips^X=accurate': 10,
#              'Y=Articles_containing_video_clips^X=precise': 13,
#              'Y=Articles_containing_video_clips^X=representation': 15,
#              'Y=Articles_containing_video_clips^X=time': 372,
#              'Y=Articles_containing_video_clips^X=common': 289,
#              'Y=Articles_containing_video_clips^X=application': 22,
#              'Y=Articles_containing_video_clips^X=compounds': 24,
#              'Y=Articles_containing_video_clips^X=vapour': 3,
#              'Y=Articles_containing_video_clips^X=lamp': 10,
#              'Y=Articles_containing_video_clips^X=emits': 6,
#              'Y=Articles_containing_video_clips^X=efficient': 10,
#              'Y=Articles_containing_video_clips^X=light': 160,
#              'Y=Articles_containing_video_clips^X=salt': 18,
#              'Y=Articles_containing_video_clips^X=chloride': 6,
#              'Y=Articles_containing_video_clips^X=has': 1012,
#              'Y=Articles_containing_video_clips^X=since': 273,
#              'Y=Articles_containing_video_clips^X=antiquity': 9,
#              'Y=Articles_containing_video_clips^X=also': 1158,
#              'Y=Articles_containing_video_clips^X=essential': 18,
#              'Y=Articles_containing_video_clips^X=having': 86,
#              'Y=Articles_containing_video_clips^X=major': 206,
#              'Y=Articles_containing_video_clips^X=biological': 31,
#              'Y=Articles_containing_video_clips^X=roles': 27,
#              'Y=Articles_containing_video_clips^X=electrolytes': 2,
#              'Y=Articles_containing_video_clips^X=although': 250,
#              'Y=Articles_containing_video_clips^X=various': 159,
#              'Y=Articles_containing_video_clips^X=body': 189,
#              'Y=Articles_containing_video_clips^X=both': 301,
#              'Y=Articles_containing_video_clips^X=beneficial': 4,
#              'Y=Articles_containing_video_clips^X=harmful': 6,
#              'Y=Articles_containing_video_clips^X=atlantic': 49,
#              'Y=Articles_containing_video_clips^X=largest': 241,
#              'Y=Articles_containing_video_clips^X=following': 119,
#              'Y=Articles_containing_video_clips^X=area': 280,
#              'Y=Articles_containing_video_clips^X=square': 58,
#              'Y=Articles_containing_video_clips^X=kilometres': 41,
#              'Y=Articles_containing_video_clips^X=sq': 31,
#              'Y=Articles_containing_video_clips^X=mi': 117,
#              'Y=Articles_containing_video_clips^X=covers': 27,
#              'Y=Articles_containing_video_clips^X=approximately': 92,
#              'Y=Articles_containing_video_clips^X=percent': 21,
#              'Y=Articles_containing_video_clips^X=name': 277,
#              'Y=Articles_containing_video_clips^X=refers': 81,
#              'Y=Articles_containing_video_clips^X=atlas': 11,
#              'Y=Articles_containing_video_clips^X=greek': 98,
#              'Y=Articles_containing_video_clips^X=mythology': 14,
#              'Y=Articles_containing_video_clips^X=making': 121,
#              'Y=Articles_containing_video_clips^X=oldest': 40,
#              'Y=Articles_containing_video_clips^X=mention': 5,
#              'Y=Articles_containing_video_clips^X=histories': 2,
#              'Y=Articles_containing_video_clips^X=herodotus': 2,
#              'Y=Articles_containing_video_clips^X=around': 252,
#              'Y=Articles_containing_video_clips^X=bc': 74,
#              'Y=Articles_containing_video_clips^X=hdt': 1,
#              'Y=Articles_containing_video_clips^X=atlantis': 16,
#              'Y=Articles_containing_video_clips^X=thalassa': 1,
#              'Y=Articles_containing_video_clips^X=c': 741,
#              'Y=Articles_containing_video_clips^X=bb': 32,
#              'Y=Articles_containing_video_clips^X=b': 603,
#              'Y=Articles_containing_video_clips^X=ac': 20,
#              'Y=Articles_containing_video_clips^X=english': 132,
#              'Y=Articles_containing_video_clips^X=term': 241,
#              'Y=Articles_containing_video_clips^X=ethiopic': 1,
#              'Y=Articles_containing_video_clips^X=derived': 53,
#              'Y=Articles_containing_video_clips^X=ethiopia': 3,
#              'Y=Articles_containing_video_clips^X=applied': 51,
#              'Y=Articles_containing_video_clips^X=southern': 143,
#              'Y=Articles_containing_video_clips^X=late': 116,
#              'Y=Articles_containing_video_clips^X=mid': 77,
#              'Y=Articles_containing_video_clips^X=th': 434,
#              'Y=Articles_containing_video_clips^X=century': 341,
#              'Y=Articles_containing_video_clips^X=europeans': 4,
#              'Y=Articles_containing_video_clips^X=oceans': 26,
#              'Y=Articles_containing_video_clips^X=synonymous': 6,
#              'Y=Articles_containing_video_clips^X=waters': 37,
#              'Y=Articles_containing_video_clips^X=beyond': 37,
#              'Y=Articles_containing_video_clips^X=strait': 17,
#              'Y=Articles_containing_video_clips^X=gibraltar': 4,
#              'Y=Articles_containing_video_clips^X=now': 151,
#              'Y=Articles_containing_video_clips^X=early': 236,
#              'Y=Articles_containing_video_clips^X=greeks': 7,
#              'Y=Articles_containing_video_clips^X=believed': 43,
#              'Y=Articles_containing_video_clips^X=gigantic': 2,
#              'Y=Articles_containing_video_clips^X=river': 165,
#              'Y=Articles_containing_video_clips^X=encircling': 1,
#              'Y=Articles_containing_video_clips^X=occupies': 12,
#              'Y=Articles_containing_video_clips^X=elongated': 7,
#              'Y=Articles_containing_video_clips^X=shaped': 43,
#              'Y=Articles_containing_video_clips^X=basin': 30,
#              'Y=Articles_containing_video_clips^X=extending': 17,
#              'Y=Articles_containing_video_clips^X=longitudinally': 2,
#              'Y=Articles_containing_video_clips^X=between': 411,
#              'Y=Articles_containing_video_clips^X=eurasia': 21,
#              'Y=Articles_containing_video_clips^X=africa': 155,
#              'Y=Articles_containing_video_clips^X=east': 260,
#              'Y=Articles_containing_video_clips^X=americas': 32,
#              'Y=Articles_containing_video_clips^X=west': 204,
#              'Y=Articles_containing_video_clips^X=component': 39,
#              'Y=Articles_containing_video_clips^X=interconnected': 3,
#              'Y=Articles_containing_video_clips^X=global': 71,
#              'Y=Articles_containing_video_clips^X=connected': 37,
#              'Y=Articles_containing_video_clips^X=north': 367,
#              'Y=Articles_containing_video_clips^X=arctic': 34,
#              'Y=Articles_containing_video_clips^X=southwest': 25,
#              'Y=Articles_containing_video_clips^X=indian': 103,
#              'Y=Articles_containing_video_clips^X=southeast': 52,
#              'Y=Articles_containing_video_clips^X=south': 330,
#              'Y=Articles_containing_video_clips^X=definitions': 10,
#              'Y=Articles_containing_video_clips^X=describe': 27,
#              'Y=Articles_containing_video_clips^X=southward': 7,
#              'Y=Articles_containing_video_clips^X=antarctica': 13,
#              'Y=Articles_containing_video_clips^X=equator': 9,
#              'Y=Articles_containing_video_clips^X=subdivides': 1,
#              'Y=Articles_containing_video_clips^X=central': 192,
#              'Y=Articles_containing_video_clips^X=america': 182,
#              'Y=Articles_containing_video_clips^X=while': 328,
#              'Y=Articles_containing_video_clips^X=geographically': 5,
#              'Y=Articles_containing_video_clips^X=character': 45,
#              'Y=Articles_containing_video_clips^X=europe': 162,
#              'Y=English-language_journals': 22,
#              'Y=English-language_journals^X=algorithms': 1,
#              'Y=English-language_journals^X=ANY': 2260,
#              'Y=English-language_journals^X=is': 69,
#              'Y=English-language_journals^X=a': 44,
#              'Y=English-language_journals^X=peer': 19,
#              'Y=English-language_journals^X=reviewed': 18,
#              'Y=English-language_journals^X=open': 2,
#              'Y=English-language_journals^X=access': 3,
#              'Y=English-language_journals^X=mathematics': 3,
#              'Y=English-language_journals^X=journal': 87,
#              'Y=English-language_journals^X=covering': 6,
#              'Y=English-language_journals^X=all': 8,
#              'Y=English-language_journals^X=aspects': 5,
#              'Y=English-language_journals^X=of': 113,
#              'Y=English-language_journals^X=algorithm': 1,
#              'Y=English-language_journals^X=studies': 2,
#              'Y=English-language_journals^X=including': 2,
#              'Y=English-language_journals^X=theory': 3,
#              'Y=English-language_journals^X=experiment': 1,
#              'Y=English-language_journals^X=design': 1,
#              'Y=English-language_journals^X=analysis': 1,
#              'Y=English-language_journals^X=and': 70,
#              'Y=English-language_journals^X=results': 1,
#              'Y=English-language_journals^X=coverage': 1,
#              'Y=English-language_journals^X=also': 5,
#              'Y=English-language_journals^X=includes': 1,
#              'Y=English-language_journals^X=computer': 1,
#              'Y=English-language_journals^X=data': 2,
#              'Y=English-language_journals^X=information': 2,
#              'Y=English-language_journals^X=systems': 2,
#              'Y=English-language_journals^X=software': 2,
#              'Y=English-language_journals^X=engineering': 1,
#              'Y=English-language_journals^X=artificial': 1,
#              'Y=English-language_journals^X=intelligence': 1,
#              'Y=English-language_journals^X=automation': 1,
#              'Y=English-language_journals^X=control': 1,
#              'Y=English-language_journals^X=the': 189,
#              'Y=English-language_journals^X=published': 32,
#              'Y=English-language_journals^X=by': 30,
#              'Y=English-language_journals^X=mdpi': 1,
#              'Y=English-language_journals^X=was': 26,
#              'Y=English-language_journals^X=established': 11,
#              'Y=English-language_journals^X=in': 82,
#              'Y=English-language_journals^X=editor': 18,
#              'Y=English-language_journals^X=chief': 11,
#              'Y=English-language_journals^X=kazuo': 1,
#              'Y=English-language_journals^X=iwama': 1,
#              'Y=English-language_journals^X=kyoto': 1,
#              'Y=English-language_journals^X=university': 10,
#              'Y=English-language_journals^X=publishing': 6,
#              'Y=English-language_journals^X=formats': 1,
#              'Y=English-language_journals^X=include': 1,
#              'Y=English-language_journals^X=reviews': 7,
#              'Y=English-language_journals^X=original': 8,
#              'Y=English-language_journals^X=research': 19,
#              'Y=English-language_journals^X=articles': 14,
#              'Y=English-language_journals^X=short': 2,
#              'Y=English-language_journals^X=communications': 3,
#              'Y=Windows_games': 256,
#              'Y=Windows_games^X=asteroids': 7,
#              'Y=Windows_games^X=ANY': 38969,
#              'Y=Windows_games^X=is': 608,
#              'Y=Windows_games^X=an': 173,
#              'Y=Windows_games^X=arcade': 41,
#              'Y=Windows_games^X=space': 27,
#              'Y=Windows_games^X=shooter': 64,
#              'Y=Windows_games^X=released': 381,
#              'Y=Windows_games^X=in': 938,
#              'Y=Windows_games^X=november': 40,
#              'Y=Windows_games^X=by': 619,
#              'Y=Windows_games^X=atari': 21,
#              'Y=Windows_games^X=inc': 11,
#              'Y=Windows_games^X=and': 1350,
#              'Y=Windows_games^X=designed': 35,
#              'Y=Windows_games^X=lyle': 1,
#              'Y=Windows_games^X=rains': 2,
#              'Y=Windows_games^X=ed': 3,
#              'Y=Windows_games^X=logg': 4,
#              'Y=Windows_games^X=the': 2742,
#              'Y=Windows_games^X=player': 169,
#              'Y=Windows_games^X=controls': 8,
#              'Y=Windows_games^X=a': 1056,
#              'Y=Windows_games^X=spaceship': 1,
#              'Y=Windows_games^X=asteroid': 2,
#              'Y=Windows_games^X=field': 3,
#              'Y=Windows_games^X=which': 130,
#              'Y=Windows_games^X=periodically': 1,
#              'Y=Windows_games^X=traversed': 1,
#              'Y=Windows_games^X=flying': 2,
#              'Y=Windows_games^X=saucers': 3,
#              'Y=Windows_games^X=object': 4,
#              'Y=Windows_games^X=of': 1086,
#              'Y=Windows_games^X=game': 1020,
#              'Y=Windows_games^X=to': 633,
#              'Y=Windows_games^X=shoot': 9,
#              'Y=Windows_games^X=destroy': 4,
#              'Y=Windows_games^X=while': 35,
#              'Y=Windows_games^X=not': 45,
#              'Y=Windows_games^X=colliding': 1,
#              'Y=Windows_games^X=with': 215,
#              'Y=Windows_games^X=either': 6,
#              'Y=Windows_games^X=or': 75,
#              'Y=Windows_games^X=being': 35,
#              'Y=Windows_games^X=hit': 6,
#              'Y=Windows_games^X=counter': 10,
#              'Y=Windows_games^X=fire': 3,
#              'Y=Windows_games^X=becomes': 5,
#              'Y=Windows_games^X=harder': 1,
#              'Y=Windows_games^X=as': 410,
#              'Y=Windows_games^X=number': 22,
#              'Y=Windows_games^X=increases': 1,
#              'Y=Windows_games^X=was': 610,
#              'Y=Windows_games^X=conceived': 4,
#              'Y=Windows_games^X=during': 28,
#              'Y=Windows_games^X=meeting': 2,
#              'Y=Windows_games^X=between': 24,
#              'Y=Windows_games^X=used': 33,
#              'Y=Windows_games^X=hardware': 6,
#              'Y=Windows_games^X=developed': 186,
#              'Y=Windows_games^X=howard': 1,
#              'Y=Windows_games^X=delman': 1,
#              'Y=Windows_games^X=previously': 9,
#              'Y=Windows_games^X=for': 488,
#              'Y=Windows_games^X=lunar': 2,
#              'Y=Windows_games^X=lander': 1,
#              'Y=Windows_games^X=based': 102,
#              'Y=Windows_games^X=on': 459,
#              'Y=Windows_games^X=unfinished': 2,
#              'Y=Windows_games^X=titled': 15,
#              'Y=Windows_games^X=cosmos': 1,
#              'Y=Windows_games^X=inspired': 11,
#              'Y=Windows_games^X=spacewar': 1,
#              'Y=Windows_games^X=computer': 80,
#              'Y=Windows_games^X=both': 31,
#              'Y=Windows_games^X=early': 13,
#              'Y=Windows_games^X=em': 8,
#              'Y=Windows_games^X=up': 28,
#              'Y=Windows_games^X=video': 200,
#              'Y=Windows_games^X=games': 193,
#              'Y=Windows_games^X=u': 398,
#              'Y=Windows_games^X=b': 55,
#              'Y=Windows_games^X=physics': 6,
#              'Y=Windows_games^X=model': 7,
#              'Y=Windows_games^X=control': 13,
#              'Y=Windows_games^X=scheme': 4,
#              'Y=Windows_games^X=were': 80,
#              'Y=Windows_games^X=derived': 3,
#              'Y=Windows_games^X=from': 136,
#              'Y=Windows_games^X=these': 15,
#              'Y=Windows_games^X=earlier': 4,
#              'Y=Windows_games^X=refined': 1,
#              'Y=Windows_games^X=through': 49,
#              'Y=Windows_games^X=trial': 1,
#              'Y=Windows_games^X=error': 1,
#              'Y=Windows_games^X=rendered': 7,
#              'Y=Windows_games^X=vector': 2,
#              'Y=Windows_games^X=display': 1,
#              'Y=Windows_games^X=two': 55,
#              'Y=Windows_games^X=dimensional': 3,
#              'Y=Windows_games^X=view': 3,
#              'Y=Windows_games^X=that': 137,
#              'Y=Windows_games^X=wraps': 1,
#              'Y=Windows_games^X=around': 18,
#              'Y=Windows_games^X=screen': 8,
#              'Y=Windows_games^X=axes': 1,
#              'Y=Windows_games^X=acclaimed': 13,
#              'Y=Windows_games^X=players': 63,
#              'Y=Windows_games^X=critics': 30,
#              'Y=Windows_games^X=its': 190,
#              'Y=Windows_games^X=graphics': 43,
#              'Y=Windows_games^X=addictive': 1,
#              'Y=Windows_games^X=gameplay': 72,
#              'Y=Windows_games^X=one': 100,
#              'Y=Windows_games^X=first': 192,
#              'Y=Windows_games^X=major': 26,
#              'Y=Windows_games^X=hits': 3,
#              'Y=Windows_games^X=golden': 5,
#              'Y=Windows_games^X=age': 17,
#              'Y=Windows_games^X=sold': 43,
#              'Y=Windows_games^X=over': 55,
#              'Y=Windows_games^X=cabinets': 1,
#              'Y=Windows_games^X=proved': 2,
#              'Y=Windows_games^X=popular': 29,
#              'Y=Windows_games^X=influential': 5,
#              'Y=Windows_games^X=developers': 17,
#              'Y=Windows_games^X=it': 382,
#              'Y=Windows_games^X=has': 139,
#              'Y=Windows_games^X=since': 34,
#              'Y=Windows_games^X=been': 90,
#              'Y=Windows_games^X=ported': 48,
#              'Y=Windows_games^X=multiple': 10,
#              'Y=Windows_games^X=platforms': 36,
#              'Y=Windows_games^X=widely': 9,
#              'Y=Windows_games^X=imitated': 1,
#              'Y=Windows_games^X=directly': 1,
#              'Y=Windows_games^X=influenced': 9,
#              'Y=Windows_games^X=often': 11,
#              'Y=Windows_games^X=cloned': 1,
#              'Y=Windows_games^X=defender': 1,
#              'Y=Windows_games^X=gravitar': 1,
#              'Y=Windows_games^X=well': 49,
#              'Y=Windows_games^X=many': 42,
#              'Y=Windows_games^X=other': 78,
#              'Y=American_people_of_Irish_descent': 694,
#              'Y=American_film_directors^X=sir': 3,
#              'Y=American_people_of_Irish_descent^X=sir': 6,
#              'Y=American_people_of_Irish_descent^X=ANY': 101015,
#              'Y=American_film_directors^X=alfred': 8,
#              'Y=American_people_of_Irish_descent^X=alfred': 11,
#              'Y=American_film_directors^X=joseph': 10,
#              'Y=American_people_of_Irish_descent^X=joseph': 57,
#              'Y=American_film_directors^X=hitchcock': 11,
#              'Y=American_people_of_Irish_descent^X=hitchcock': 11,
#              'Y=American_film_directors^X=kbe': 1,
#              'Y=American_people_of_Irish_descent^X=kbe': 2,
#              'Y=American_film_directors^X=august': 48,
#              'Y=American_people_of_Irish_descent^X=august': 109,
#              'Y=American_people_of_Irish_descent^X=u': 1143,
#              'Y=American_people_of_Irish_descent^X=april': 102,
#              'Y=American_people_of_Irish_descent^X=was': 1502,
#              'Y=American_film_directors^X=an': 479,
#              'Y=American_people_of_Irish_descent^X=an': 935,
#              'Y=American_film_directors^X=english': 8,
#              'Y=American_people_of_Irish_descent^X=english': 17,
#              'Y=American_film_directors^X=film': 676,
#              'Y=American_people_of_Irish_descent^X=film': 457,
#              'Y=American_people_of_Irish_descent^X=director': 107,
#              'Y=American_people_of_Irish_descent^X=and': 3753,
#              'Y=American_people_of_Irish_descent^X=producer': 88,
#              'Y=American_film_directors^X=often': 30,
#              'Y=American_people_of_Irish_descent^X=often': 43,
#              'Y=American_film_directors^X=nicknamed': 3,
#              'Y=American_people_of_Irish_descent^X=nicknamed': 16,
#              'Y=American_film_directors^X=the': 2639,
#              'Y=American_people_of_Irish_descent^X=the': 6123,
#              'Y=American_film_directors^X=master': 8,
#              'Y=American_people_of_Irish_descent^X=master': 11,
#              'Y=American_film_directors^X=of': 1195,
#              'Y=American_people_of_Irish_descent^X=of': 3089,
#              'Y=American_film_directors^X=suspense': 5,
#              'Y=American_people_of_Irish_descent^X=suspense': 10,
#              'Y=American_film_directors^X=he': 773,
#              'Y=American_people_of_Irish_descent^X=he': 1519,
#              'Y=American_film_directors^X=pioneered': 3,
#              'Y=American_people_of_Irish_descent^X=pioneered': 7,
#              'Y=American_film_directors^X=many': 55,
#              'Y=American_people_of_Irish_descent^X=many': 86,
#              'Y=American_film_directors^X=techniques': 7,
#              'Y=American_people_of_Irish_descent^X=techniques': 6,
#              'Y=American_film_directors^X=in': 1240,
#              'Y=American_people_of_Irish_descent^X=in': 3454,
#              'Y=American_film_directors^X=psychological': 13,
#              'Y=American_people_of_Irish_descent^X=psychological': 9,
#              'Y=American_film_directors^X=thriller': 44,
#              'Y=American_people_of_Irish_descent^X=thriller': 42,
#              'Y=American_film_directors^X=genres': 14,
#              'Y=American_people_of_Irish_descent^X=genres': 11,
#              'Y=American_film_directors^X=after': 73,
#              'Y=American_people_of_Irish_descent^X=after': 237,
#              'Y=American_people_of_Irish_descent^X=a': 1960,
#              'Y=American_film_directors^X=successful': 32,
#              'Y=American_people_of_Irish_descent^X=successful': 55,
#              'Y=American_film_directors^X=career': 106,
#              'Y=American_people_of_Irish_descent^X=career': 235,
#              'Y=American_film_directors^X=british': 17,
#              'Y=American_people_of_Irish_descent^X=british': 28,
#              'Y=American_film_directors^X=cinema': 24,
#              'Y=American_people_of_Irish_descent^X=cinema': 16,
#              'Y=American_film_directors^X=both': 42,
#              'Y=American_people_of_Irish_descent^X=both': 97,
#              'Y=American_film_directors^X=silent': 21,
#              'Y=American_people_of_Irish_descent^X=silent': 7,
#              'Y=American_film_directors^X=films': 369,
#              'Y=American_people_of_Irish_descent^X=films': 222,
#              'Y=American_film_directors^X=early': 33,
#              'Y=American_people_of_Irish_descent^X=early': 86,
#              'Y=American_film_directors^X=talkies': 5,
#              'Y=American_people_of_Irish_descent^X=talkies': 2,
#              'Y=American_film_directors^X=renowned': 5,
#              'Y=American_people_of_Irish_descent^X=renowned': 10,
#              'Y=American_film_directors^X=as': 569,
#              'Y=American_people_of_Irish_descent^X=as': 1319,
#              'Y=American_film_directors^X=england': 4,
#              'Y=American_people_of_Irish_descent^X=england': 14,
#              'Y=American_film_directors^X=s': 491,
#              'Y=American_people_of_Irish_descent^X=s': 1186,
#              'Y=American_film_directors^X=best': 294,
#              'Y=American_people_of_Irish_descent^X=best': 334,
#              'Y=American_film_directors^X=moved': 19,
#              'Y=American_people_of_Irish_descent^X=moved': 32,
#              'Y=American_film_directors^X=to': 434,
#              'Y=American_people_of_Irish_descent^X=to': 1477,
#              'Y=American_film_directors^X=hollywood': 66,
#              'Y=American_people_of_Irish_descent^X=hollywood': 64,
#              'Y=American_film_directors^X=became': 44,
#              'Y=American_people_of_Irish_descent^X=became': 175,
#              'Y=American_film_directors^X=us': 12,
#              'Y=American_people_of_Irish_descent^X=us': 44,
#              'Y=American_film_directors^X=citizen': 11,
#              'Y=American_people_of_Irish_descent^X=citizen': 12,
#              'Y=American_film_directors^X=over': 39,
#              'Y=American_people_of_Irish_descent^X=over': 103,
#              'Y=American_film_directors^X=spanning': 6,
#              'Y=American_people_of_Irish_descent^X=spanning': 5,
#              'Y=American_film_directors^X=more': 58,
#              'Y=American_people_of_Irish_descent^X=more': 105,
#              'Y=American_film_directors^X=than': 43,
#              'Y=American_people_of_Irish_descent^X=than': 77,
#              'Y=American_film_directors^X=half': 5,
#              'Y=American_people_of_Irish_descent^X=half': 20,
#              'Y=American_film_directors^X=century': 14,
#              'Y=American_people_of_Irish_descent^X=century': 40,
#              'Y=American_film_directors^X=fashioned': 1,
#              'Y=American_people_of_Irish_descent^X=fashioned': 1,
#              'Y=American_film_directors^X=for': 830,
#              'Y=American_people_of_Irish_descent^X=for': 1408,
#              'Y=American_film_directors^X=himself': 20,
#              'Y=American_people_of_Irish_descent^X=himself': 20,
#              'Y=American_film_directors^X=distinctive': 7,
#              'Y=American_people_of_Irish_descent^X=distinctive': 9,
#              'Y=American_film_directors^X=recognisable': 1,
#              'Y=American_people_of_Irish_descent^X=recognisable': 1,
#              'Y=American_film_directors^X=directorial': 27,
#              'Y=American_people_of_Irish_descent^X=directorial': 8,
#              'Y=American_film_directors^X=style': 16,
#              'Y=American_people_of_Irish_descent^X=style': 31,
#              'Y=American_film_directors^X=use': 11,
#              'Y=American_people_of_Irish_descent^X=use': 21,
#              'Y=American_film_directors^X=camera': 9,
#              'Y=American_people_of_Irish_descent^X=camera': 3,
#              'Y=American_film_directors^X=made': 65,
#              'Y=American_people_of_Irish_descent^X=made': 114,
#              'Y=American_film_directors^X=move': 5,
#              'Y=American_people_of_Irish_descent^X=move': 9,
#              'Y=American_film_directors^X=way': 15,
#              'Y=American_people_of_Irish_descent^X=way': 19,
#              'Y=American_film_directors^X=that': 101,
#              'Y=American_people_of_Irish_descent^X=that': 233,
#              'Y=American_film_directors^X=mimics': 1,
#              'Y=American_people_of_Irish_descent^X=mimics': 1,
#              'Y=American_film_directors^X=person': 9,
#              'Y=American_people_of_Irish_descent^X=person': 20,
#              'Y=American_film_directors^X=gaze': 1,
#              'Y=American_people_of_Irish_descent^X=gaze': 1,
#              'Y=American_film_directors^X=forcing': 1,
#              'Y=American_people_of_Irish_descent^X=forcing': 2,
#              'Y=American_film_directors^X=viewers': 3,
#              'Y=American_people_of_Irish_descent^X=viewers': 2,
#              'Y=American_film_directors^X=engage': 2,
#              'Y=American_people_of_Irish_descent^X=engage': 1,
#              'Y=American_film_directors^X=form': 8,
#              'Y=American_people_of_Irish_descent^X=form': 10,
#              'Y=American_film_directors^X=voyeurism': 1,
#              'Y=American_people_of_Irish_descent^X=voyeurism': 1,
#              'Y=American_film_directors^X=framed': 2,
#              'Y=American_people_of_Irish_descent^X=framed': 2,
#              'Y=American_film_directors^X=shots': 3,
#              'Y=American_people_of_Irish_descent^X=shots': 3,
#              'Y=American_film_directors^X=maximise': 1,
#              'Y=American_people_of_Irish_descent^X=maximise': 1,
#              'Y=American_film_directors^X=anxiety': 1,
#              'Y=American_people_of_Irish_descent^X=anxiety': 1,
#              'Y=American_film_directors^X=fear': 5,
#              'Y=American_people_of_Irish_descent^X=fear': 4,
#              'Y=American_film_directors^X=or': 52,
#              'Y=American_people_of_Irish_descent^X=or': 86,
#              'Y=American_film_directors^X=empathy': 2,
#              'Y=American_people_of_Irish_descent^X=empathy': 1,
#              'Y=American_film_directors^X=used': 9,
#              'Y=American_people_of_Irish_descent^X=used': 19,
#              'Y=American_film_directors^X=innovative': 7,
#              'Y=American_people_of_Irish_descent^X=innovative': 5,
#              'Y=American_film_directors^X=editing': 8,
#              'Y=American_people_of_Irish_descent^X=editing': 2,
#              'Y=American_film_directors^X=his': 694,
#              'Y=American_people_of_Irish_descent^X=his': 1259,
#              'Y=American_film_directors^X=stories': 9,
#              'Y=American_people_of_Irish_descent^X=stories': 30,
#              'Y=American_film_directors^X=feature': 56,
#              'Y=American_people_of_Irish_descent^X=feature': 22,
#              'Y=American_film_directors^X=fugitives': 1,
#              'Y=American_people_of_Irish_descent^X=fugitives': 1,
#              'Y=American_film_directors^X=on': 289,
#              'Y=American_people_of_Irish_descent^X=on': 788,
#              'Y=American_film_directors^X=run': 14,
#              'Y=American_people_of_Irish_descent^X=run': 31,
#              'Y=American_film_directors^X=from': 127,
#              'Y=American_people_of_Irish_descent^X=from': 544,
#              'Y=American_film_directors^X=law': 5,
#              'Y=American_people_of_Irish_descent^X=law': 44,
#              'Y=American_film_directors^X=alongside': 7,
#              'Y=American_people_of_Irish_descent^X=alongside': 19,
#              'Y=American_film_directors^X=icy': 1,
#              'Y=American_people_of_Irish_descent^X=icy': 1,
#              'Y=American_film_directors^X=blonde': 1,
#              'Y=American_people_of_Irish_descent^X=blonde': 4,
#              'Y=American_film_directors^X=female': 3,
#              'Y=American_people_of_Irish_descent^X=female': 41,
#              'Y=American_film_directors^X=characters': 21,
#              'Y=American_people_of_Irish_descent^X=characters': 21,
#              'Y=American_film_directors^X=have': 54,
#              'Y=American_people_of_Irish_descent^X=have': 119,
#              'Y=American_film_directors^X=twist': 2,
#              'Y=American_people_of_Irish_descent^X=twist': 2,
#              'Y=American_film_directors^X=endings': 1,
#              'Y=American_people_of_Irish_descent^X=endings': 1,
#              'Y=American_film_directors^X=thrilling': 1,
#              'Y=American_people_of_Irish_descent^X=thrilling': 1,
#              'Y=American_film_directors^X=plots': 2,
#              'Y=American_people_of_Irish_descent^X=plots': 2,
#              'Y=American_film_directors^X=featuring': 5,
#              'Y=American_people_of_Irish_descent^X=featuring': 6,
#              'Y=American_film_directors^X=depictions': 2,
#              'Y=American_people_of_Irish_descent^X=depictions': 2,
#              'Y=American_film_directors^X=violence': 6,
#              'Y=American_people_of_Irish_descent^X=violence': 5,
#              'Y=American_film_directors^X=murder': 5,
#              'Y=American_people_of_Irish_descent^X=murder': 8,
#              'Y=American_film_directors^X=crime': 32,
#              'Y=American_people_of_Irish_descent^X=crime': 34,
#              'Y=American_film_directors^X=mysteries': 2,
#              'Y=American_people_of_Irish_descent^X=mysteries': 1,
#              'Y=American_film_directors^X=however': 10,
#              'Y=American_people_of_Irish_descent^X=however': 23,
#              'Y=American_film_directors^X=are': 46,
#              'Y=American_people_of_Irish_descent^X=are': 43,
#              'Y=American_film_directors^X=decoys': 1,
#              'Y=American_people_of_Irish_descent^X=decoys': 1,
#              'Y=American_film_directors^X=macguffins': 1,
#              'Y=American_people_of_Irish_descent^X=macguffins': 1,
#              'Y=American_film_directors^X=serve': 1,
#              'Y=American_people_of_Irish_descent^X=serve': 12,
#              'Y=American_film_directors^X=themes': 10,
#              'Y=American_people_of_Irish_descent^X=themes': 7,
#              'Y=American_film_directors^X=examinations': 1,
#              'Y=American_people_of_Irish_descent^X=examinations': 1,
#              'Y=American_film_directors^X=also': 200,
#              'Y=American_people_of_Irish_descent^X=also': 313,
#              'Y=American_film_directors^X=borrow': 1,
#              'Y=American_people_of_Irish_descent^X=borrow': 1,
#              'Y=American_film_directors^X=psychoanalysis': 1,
#              'Y=American_people_of_Irish_descent^X=psychoanalysis': 1,
#              'Y=American_film_directors^X=strong': 7,
#              'Y=American_people_of_Irish_descent^X=strong': 13,
#              'Y=American_film_directors^X=sexual': 1,
#              'Y=American_people_of_Irish_descent^X=sexual': 3,
#              'Y=American_film_directors^X=overtones': 1,
#              'Y=American_people_of_Irish_descent^X=overtones': 1,
#              'Y=American_film_directors^X=through': 15,
#              'Y=American_people_of_Irish_descent^X=through': 47,
#              'Y=American_film_directors^X=cameo': 2,
#              'Y=American_people_of_Irish_descent^X=cameo': 5,
#              'Y=American_film_directors^X=appearances': 13,
#              'Y=American_people_of_Irish_descent^X=appearances': 28,
#              'Y=American_film_directors^X=own': 26,
#              'Y=American_people_of_Irish_descent^X=own': 32,
#              ...})

# %% [markdown]
# Posterior
# $$log( P(Y = y_k | x) )  = log \big( \frac{count(Y= y_k) + m q_y}{count( Y= ANY)+ m}   \big)  +  \sum_{i=1}^d \frac{Count(X= x_j\ \&\ Y = y_k)+ m q_x}{  Count(X= ANY\ \&\ Y = y_k) + m } $$
# <br/>
# $$ y_{pred} = argmax_{y_i }\ \ log( P(Y = y_i | x) )  $$
# $ q_y = \frac{1}{No\ of\ Class}$ <br/>
# $q_x = \frac{1}{No\ of\ words}$ <br/>

# %% [markdown]
# Metric Evaluation
# $$ Accuracy = \sum_i^{No\ of\ test}  1_{ y_{pred}\ in\ Labels_i }$$

# %%
f =  open('DBPedia.verysmall/verysmall_test.txt', 'r')
test_size = 0
acc = 0
for article in f:
    
    try :        
            labels, line = article.split('\t')
    except:
        continue
    test_size = test_size + 1
            
    labels = labels.split(',')
    labels = [label.replace(" ","") for label in labels]
            
    line  = re.sub(r'[^a-zA-Z]', " ",re.sub(r'<.*>',"", line) ).split()[:-1]
    likli = []
    for label in cls :
        prob = 0
        for word in line :
            word  = word.lower()
            word  = word.replace(" ","")
                
            prob = prob + math.log( ( C.get('Y='+label + '^X=' +word, 0) + q_x )* 1./  ( C.get('Y='+label + '^X=ANY', 0) + 1 ) ) 
        prob = prob + math.log( ( C.get('Y='+label, 0) + q_y ) * 1./ (C['Y=ANY'] + 1) )
        likli.append((label,prob))
    predict = sorted(likli, key = lambda x: -x[1])[0][0]
    acc = acc + int (predict in labels)
        
        
        
f.close()

print("Accuracy = ",acc *1./test_size)
# Out:
# Accuracy =  0.9919839679358717
